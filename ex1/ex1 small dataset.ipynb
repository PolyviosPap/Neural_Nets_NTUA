# %%
#Εισαγωγή του dataset.
import pandas as pd
df = pd.read_csv("sonar.all-data", header=None)

# %% [markdown]
# #### Παρουσίαση του dataset.
# Στόχος του dataset είναι να εκπαιδεύσει ένα νευρωνικό δίκτυο να διακρίνει το μέσο μετάδοσης σημάτων σόναρ: μεταλικός κίλυνδρος ή κίλυνδρος βράχου.

# %% [markdown]
# ####  Αριθμός δειγμάτων και χαρακτηριστικών, είδος χαρακτηριστικών. Υπάρχουν μη διατεταγμένα χαρακτηριστικά και ποια είναι αυτά;

# %%
print(df)
print(df.shape)
# Out:
#          0       1       2       3       4       5       6       7       8   \
# 0    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 5    0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
# 6    0.0317  0.0956  0.1321  0.1408  0.1674  0.1710  0.0731  0.1401  0.2083
# 7    0.0519  0.0548  0.0842  0.0319  0.1158  0.0922  0.1027  0.0613  0.1465
# 8    0.0223  0.0375  0.0484  0.0475  0.0647  0.0591  0.0753  0.0098  0.0684
# 9    0.0164  0.0173  0.0347  0.0070  0.0187  0.0671  0.1056  0.0697  0.0962
# 10   0.0039  0.0063  0.0152  0.0336  0.0310  0.0284  0.0396  0.0272  0.0323
# ...

# %% [markdown]
# Έχουμε 208 δείγματα (111 μέταλο, 97 πέτρα) και 61 χαρακτηριστικά.
#
# #Για το είδος των χαρακτηριστικών:
# #The file ... contains ... patterns obtained by bouncing sonar signals off a ... cylinder at various angles and under various conditions.
# #Δεν έχει άλλη εξήγηση, πρέπει να το ψάξουμε αλλιώς;;;
#
# Μη διατεταγμένα χαρακτηριστικά υπάρχουν στη 61η στήλη η οποία περιέχει το είδος του μέσου μετάδοσης: M (metal) ή R(rock).

# %% [markdown]
# #### Υπάρχουν επικεφαλίδες; Αρίθμηση γραμμών;
# Όχι.

# %% [markdown]
# #### Ποιες είναι οι ετικέτες των κλάσεων και σε ποια κολόνα βρίσκονται;
# #Εννοεί ό,τι έχουμε γράψει πάνω για την 61η στήλη;;;

# %% [markdown]
# #### Χρειάστηκε να κάνετε μετατροπές στα αρχεία text και ποιες?
# #Από lab4 2.1_classification:
#
# Τα χαρακτηριστικά είναι σε γραμμές και τα δείγματα σε κολόνες. check.
#
# Δεν έχουμε ούτε αρίθμηση, ούτε επικεφαλίδες. check.
#
# Δεν υπάρχουν απουσιάζουσες τιμές. check. #πως θα γίνει έλεγχος;;;
#
# Για τα κατηγορικά χαρακτηριστικά:

# %%
import pandas as pd

#Οι κατηγορικές μεταβλητές υπάρχουν στην 61η στήλη. 
dummies = pd.get_dummies(df, columns=[60])
print(dummies)
# Μετατρέπουμε σε αριθμητικές τιμές (pd.to_numeric) και σε numpy array (.values)
np_dummies = dummies.apply(pd.to_numeric).values
print(np_dummies)
# Out:
#           0       1       2       3       4       5       6       7       8  \
# 0    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 5    0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
# 6    0.0317  0.0956  0.1321  0.1408  0.1674  0.1710  0.0731  0.1401  0.2083
# 7    0.0519  0.0548  0.0842  0.0319  0.1158  0.0922  0.1027  0.0613  0.1465
# 8    0.0223  0.0375  0.0484  0.0475  0.0647  0.0591  0.0753  0.0098  0.0684
# 9    0.0164  0.0173  0.0347  0.0070  0.0187  0.0671  0.1056  0.0697  0.0962
# 10   0.0039  0.0063  0.0152  0.0336  0.0310  0.0284  0.0396  0.0272  0.0323
# ...
